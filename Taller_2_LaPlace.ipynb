# %% [markdown]
# <a href="https://colab.research.google.com/github/juramirezmon/Senales_y_sistemas/blob/main/Taller_2_LaPlace.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Transformada de Laplace

# %% [markdown]
# Consultar y realizar los ejercicios propuestos en el cuaderno
# de Colab Convolución.

# %% [markdown]
# https://github.com/juramirezmon/Senales_y_sistemas/blob/main/2_SLIT/1_Convolucion.ipynb

# %% [markdown]
# Consultar y realizar los ejercicios propuestos en el cuaderno
# de Colab Respuesta impulso.

# %% [markdown]
# https://github.com/juramirezmon/Senales_y_sistemas/blob/main/2_SLIT/2_Respuesta_Impulso.ipynb

# %% [markdown]
# ## Punto 3

# %% [markdown]
# Demuestre si los siguientes sistemas de la forma y = H{x},
# son sistemas lineales e invariantes en el tiempo (SLIT) (si-
# mule los sistemas en Python):
#
# • $$y[n] = \frac{x[n]}{3} + 2x[n-1] - y[n-1]$$ .

# %% [markdown]
# ![WhatsApp Image 2025-06-24 at 10.54.16 AM.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# • $$y[n] = \sum_{k=-\infty}^{n} x^2[k]$$

# %% [markdown]
# • y[n] = median(x[n]); donde median es la función mediana sobre una ventana de tamaño 3.

# %% [markdown]
# • y(t) = Ax(t) + B; A, B ∈ R.
